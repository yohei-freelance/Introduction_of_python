# %% [markdown]
# # 属性の変更、削除（組み込み関数による方法）
#
# 6-1 で説明しましたが、属性の操作は「代入」だけではなく、以下のような組み込み関数を使うことができます。
#
# ---
# ```Python
# setattr(オブジェクト, 属性文字列, 式)    # 追加・変更
# delattr(オブジェクト, 属性文字列)        # 削除
# ```
# ---
#
# これらの組み込み関数により、属性の名前がプログラムを実行してから定まるときにも、属性の操作することができます。
# すなわち、上の属性文字列を書くべきところで、文字列に評価される式を書くことができます。

# %% [markdown]
# # 第6回本課題
#
# **この課題では、Python プログラムファイルと、jupyter-notebook の両方を提出してください。**
#
# ## 1. クラス `UTCourse` の定義
# 東大の講義データを扱う Python クラス、`UTCourse` を定義するモジュールファイル `utas.py` を作成してください。クラス `UTCourse` は:
#
# 1. UTCourse オブジェクトは生成時に辞書として与えられる引数のキーを属性名、値をその属性値として持ちます。
# 1. `year` 属性は開講年度を**数値**として持ちます。
#
# UTCourse オブジェクトの生成は以下のようにおこないます。
#
# ```Python
# import utas
# uc = utas.UTCourse({"year":2018, "title_j":"コンピュータシステム概論", "name_j":"小林克志", "Teaching_Methods": "講義では....", .....})
# ```
#
# ## 2. json ファイルの読み込み
#
# 東京大学授業カタログ `catalog-2018.json` を `json.load()` で読み込み、登録された講義すべてに対応する、`UTCourse` オブジェクトをリストで返す関数、`utcourses()` 定義してください。
#
# ```Python
# import utas
# def utcourses():
#     関数の定義
#
# utcs = utcourses()
# ```
#
# ## 3. `UTCourse` オブジェクトの利用
# `UTCourse` オブジェクトリストから、属性`Common_Course_Code`の値が与えられた文字列と等しい全てのオブジェクトを返す関数、`filter_ccc(s, utcs)` を実装してください。
#     `filter_ccc()` は第一引数 `s` に検索文字列、第二引数 `utcs` に `UTCourse` オブジェクトのリストを与えます。
# たとえば、FEN-MP4d01L1 のオブジェクトを抽出したい場合は以下のように呼ばれます。
#
# ```Python
# import utas
# def filter_ccc(s, utcs):
#     関数の定義
#
# utcs = utcourses()                      # json ファイルの読み込み
# data = filter_ccc("FEN-MP4d01L1", utcs)
# ```

# %%
class UTCourse:
    def __init__(self,dic):
        for k, v in dic.items():
            if "year" in k:
                setattr(self,k,int(v))
            else:
                setattr(self,k,v)
    def utcourses(self):
        import json
        lst = []
        with open("catalog-2018.json","r",encoding="utf-8") as f:
            j = json.load(f)
            for d in j:
                lst.append(UTCourse[d])
        return lst
    def filter_ccc(self,s,utcs):
        lst=[]
        for utc in utsc:
            if hasattr(utc,s) == True:
                lst.append(utc)
        return(tuple(lst))

# %%
import utas

# %%
def utcourses():
    import json
    lst = []
    with open("catalog-2018.json","r",encoding="utf-8") as f:
        j = json.load(f)
        for d in j:
            lst.append(utas.UTCourse(d))
    return lst

# %%
utcs = utcourses()

# %%
print(utcs)
# Out:
# [<utas.UTCourse object at 0x112bbfd30>, <utas.UTCourse object at 0x112bbfdd8>, <utas.UTCourse object at 0x112bbfda0>, <utas.UTCourse object at 0x112bbfe80>, <utas.UTCourse object at 0x112bbfe48>, <utas.UTCourse object at 0x112bbff28>, <utas.UTCourse object at 0x112bbfef0>, <utas.UTCourse object at 0x112bbff98>, <utas.UTCourse object at 0x112bc77b8>, <utas.UTCourse object at 0x112bc73c8>, <utas.UTCourse object at 0x112bc7208>, <utas.UTCourse object at 0x112bc7668>, <utas.UTCourse object at 0x112bc7518>, <utas.UTCourse object at 0x112bc7a90>, <utas.UTCourse object at 0x112bc7908>, <utas.UTCourse object at 0x112bc7f28>, <utas.UTCourse object at 0x112bc7d68>, <utas.UTCourse object at 0x112bc7160>, <utas.UTCourse object at 0x112bc70b8>, <utas.UTCourse object at 0x112bc7320>, <utas.UTCourse object at 0x112bc72b0>, <utas.UTCourse object at 0x112bc74a8>, <utas.UTCourse object at 0x112bc7438>, <utas.UTCourse object at 0x112bc75f8>, <utas.UTCourse object at 0x112bc7588>, <utas.UTCourse object at 0x112bc7748>, <utas.UTCourse object at 0x112bc76d8>, <utas.UTCourse object at 0x112bc7898>, <utas.UTCourse object at 0x112bc7828>, <utas.UTCourse object at 0x112bc7a20>, <utas.UTCourse object at 0x112bc79b0>, <utas.UTCourse object at 0x112bc7b70>, <utas.UTCourse object at 0x112bc7b00>, <utas.UTCourse object at 0x112bc7cf8>, <utas.UTCourse object at 0x112bc7c88>, <utas.UTCourse object at 0x112bc7e80>, <utas.UTCourse object at 0x112bc7e10>, <utas.UTCourse object at 0x112bc7fd0>, <utas.UTCourse object at 0x112bc7080>, <utas.UTCourse object at 0x112bc7048>, <utas.UTCourse object at 0x112bc7128>, <utas.UTCourse object at 0x112bc70f0>, <utas.UTCourse object at 0x112bc71d0>, <utas.UTCourse object at 0x112bc7198>, <utas.UTCourse object at 0x112bc7278>, <utas.UTCourse object at 0x112bc7240>, <utas.UTCourse object at 0x112bc72e8>, <utas.UTCourse object at 0x112bc7390>, <utas.UTCourse object at 0x112bc7358>, <utas.UTCourse object at 0x112bc7400>, <utas.UTCourse object at 0x112bc7470>, <utas.UTCourse object at 0x112bc74e0>, <utas.UTCourse object at 0x112bc7550>, <utas.UTCourse object at 0x112bc75c0>, <utas.UTCourse object at 0x112bc7630>, <utas.UTCourse object at 0x112bc76a0>, <utas.UTCourse object at 0x112bc7710>, <utas.UTCourse object at 0x112bc7780>, <utas.UTCourse object at 0x112bc77f0>, <utas.UTCourse object at 0x112bc7860>, <utas.UTCourse object at 0x112bc78d0>, <utas.UTCourse object at 0x112bc7978>, <utas.UTCourse object at 0x112bc7940>, <utas.UTCourse object at 0x112bc79e8>, <utas.UTCourse object at 0x112bc7a58>, <utas.UTCourse object at 0x112bc7ac8>, <utas.UTCourse object at 0x112bc7b38>, <utas.UTCourse object at 0x112bc7ba8>, <utas.UTCourse object at 0x112bc7c50>, <utas.UTCourse object at 0x112bc7c18>, <utas.UTCourse object at 0x112bc7cc0>, <utas.UTCourse object at 0x112bc7d30>, <utas.UTCourse object at 0x112bc7dd8>, <utas.UTCourse object at 0x112bc7da0>, <utas.UTCourse object at 0x112bc7e48>, <utas.UTCourse object at 0x112bc7ef0>, <utas.UTCourse object at 0x112bc7eb8>, <utas.UTCourse object at 0x112bc7f98>, <utas.UTCourse object at 0x112bc7f60>, <utas.UTCourse object at 0x112bd1550>, <utas.UTCourse object at 0x112bd10f0>, <utas.UTCourse object at 0x112bd1eb8>, <utas.UTCourse object at 0x112bd13c8>, <utas.UTCourse object at 0x112bd1240>, <utas.UTCourse object at 0x112bd1860>, <utas.UTCourse object at 0x112bd1710>, <utas.UTCourse object at 0x112bd1cf8>, <utas.UTCourse object at 0x112bd1b38>, <utas.UTCourse object at 0x112bd1080>, <utas.UTCourse object at 0x112bd11d0>, <utas.UTCourse object at 0x112bd1160>, <utas.UTCourse object at 0x112bd1358>, <utas.UTCourse object at 0x112bd12e8>, <utas.UTCourse object at 0x112bd14e0>, <utas.UTCourse object at 0x112bd1470>, <utas.UTCourse object at 0x112bd1668>, <utas.UTCourse object at 0x112bd15f8>, <utas.UTCourse object at 0x112bd17f0>, <utas.UTCourse object at 0x112bd1780>, <utas.UTCourse object at 0x112bd1978>, <utas.UTCourse object at 0x112bd1908>, <utas.UTCourse object at 0x112bd1ac8>, <utas.UTCourse object ...

# %%
def filter_ccc(s,utcs):
        lst=[]
        for utc in utcs:
            if hasattr(utc["Common_Course_Code"],s):
                lst.append(utc)
        return(tuple(lst))

# %%
filter_ccc("FEN-MP4d01L1", utcs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-f89dd983f730> in <module>()
# ----> 1 filter_ccc("FEN-MP4d01L1", utcs)
#
# <ipython-input-78-40695d1e4db3> in filter_ccc(s, utcs)
#       2         lst=[]
#       3         for utc in utcs:
# ----> 4             if hasattr(utc["Common_Course_Code"],s):
#       5                 lst.append(utc)
#       6         return(tuple(lst))
#
# TypeError: 'UTCourse' object is not subscriptable
