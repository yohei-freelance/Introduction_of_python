# %% [markdown]
# # 第5回本課題

# %% [markdown]
# csvファイル"course_keyword_list.csv"には、以下のように、キーワードとそのキーワードを含む講義題目の数が、コンマ区切りで降順に1行ずつ含まれています。 ここで講義題目は、授業データのjsonファイル"catalog-2018.json"の"title_j"キーの値に基づいています。
# ```Python
# 演習,898
# 特殊,525
# I,485
# 講義,480
# II,461
# 学,451
# 論,437
# 研究,269
# １,244
# コース,236
# ...
# ```
# このキーワードリストのcsvファイル"course_keyword_list.csv"と授業データのjsonファイル"catalog-2018.json"を使って、以下の関数count_keywordを作成してください。なお、csvファイル"course_keyword_list.csv"を読み出す際は、encoding=’utf-8’を指定してください。
#
# 関数count_keywordは、授業の開講所属学部名（理学部、工学部、法学部、など）を引数として受け取り、その学部の開講講義の題目について、キーワードリスト中の各キーワードを含む題目の数を集計して、上記と同じく、キーワードとそのキーワードを含む講義題目数の組みをコンマ区切りで講義題目数の降順でcsvファイル"output.csv"に出力します。なお、csvファイル"output.csv"を書き出す際は、encoding=’utf-8’を指定してください。
#
#
#
# ```Python
# def count_keyword(学部名）:
#         pass
#
# count_keyword("理学部")
# ```
#
# なお、辞書の要素をキーの値で並び替えるのに以下の関数`sort_dicvalue`を使用してもよいです。関数`sort_dicvalue`では、引数で受け取った辞書について、その要素のキーの値で降順で要素を並び替え、その結果をキーと値のタプルで順に返します。関数`sort_dicvalue`の返り値は、以下のように`for`文で順に取り出すことができます。
# ```Python
# def sort_dicvalue(mydic):
#     for k,v in sorted(mydic.items(), key=lambda x:x[1], reverse=True):
#         yield (k, v)
#
# for k,v in sort_dicvalue(辞書):
#     print (k,v)
# ```

# %%
import csv
import json

def sort_dicvalue(mydic):
    for k,v in sorted(mydic.items(), key=lambda x:x[1], reverse=True):
        yield (k, v)

# %%
def count_keyword(dep):
    kw_list = []
    with open("course_keyword_list.csv", "r", encoding = "utf-8") as csvf:
        dataReader = csv.reader(csvf)
        for row in dataReader:
            kw_list.append(row[0])
    print(kw_list)

# %%
count_keyword("理学部")
# Out:
# ['演習', '特殊', 'I', '講義', 'II', '学', '論', '研究', '１', 'コース', 'III', '２', '実習', '共通', '特別', '科学', '専門', 'IV', '文化', '基礎', '概論', '工学', '日本語', '英語', '実験', 'Ⅱ', 'システム', 'Ⅰ', '卒業論文', '言語', '３', '生物', 'V', '環境', '応用', '特', '社会', '数理', '外国語', '科目', '化学', '開講', '教養', '指導', 'VI', '国際', '４', '分析', '史', 'グローバル', '二', '法', '第一', '朝鮮', '韓国', '設計', '日本', 'テクスト', '論文', '中級', 'a', '物質', '現代', '2', '思想', 'VII', '初級', '総合', '５', '情報', '建築', '政治', 'ドイツ語', '中国語', '８', '心理学', '生命科学', '６', '基礎科学', '０', 'A', 'VIII', '理論', 'b', '生命', '情報学', 'イタリア語', '社会学', 'A1', 'S2', '社会科学', 'S1', 'アジア', '地球', '概説', 'プロジェクト', 'スラヴ', '自然科学', '７', '文学', 'フランス', '動物', '経済', '上級', '英語学', '倫理', '教育', '教育法', '高度', '歴史', '物理', '９', '語', '資源', '数学', '統合', '英米文学', '森林', '講読', '相関', '解析学', '広域', '会話', '語学', '国文学', '日本史', '哲学', '情報工学', 'フランス語', '計画', '中国語学', '統計', '有機化学', '環境学', '考古学', 'L', '中国文学', 'IX', '数理科学', '物理学', '構造', 'イギリス', '材料', '美術史', '西洋史', 'X', '航空宇宙', '印度', '東西文明', '進化', '比較', '情報科学', '民法', 'ロシア', 'プログラミング', 'エネルギー', '科学技術
# ...

# %%
def count_keyword(dep):
    kw_list = []
    with open("course_keyword_list.csv", "r", encoding = "utf-8") as csvf:
        dataReader = csv.reader(csvf)
        for row in dataReader:
            kw_list.append(row[0])
    df={}
    with open("catalog-2018.json", "r", encoding = "utf-8")as jsonf:
        j = json.load(jsonf)
        for d in j:
            if dep in d["department_j"]:
                for kw in kw_list:
                    if kw in d["title_j"]:
                        df[kw] = df.get(kw,0) + 1
    with open("output.csv", "w", encoding = "utf-8") as csvo:
        dataWriter = csv.writer(csvo,lineterminator="\n")
        for k,v in sort_dicvalue(df):
            print (k,v)

# %%
count_keyword("理学部")
# Out:
# 学 369
# I 164
# 物 126
# II 87
# 論 66
# 化 65
# 特 64
# 化学 61
# 科 60
# 数 59
# 科学 58
# 演習 58
# 生物 55
# 特別 52
# 物理 48
# 地 47
# 数学 43
# 理学 42
# 地球 41
# 解 40
# X 40
# 解析 38
# 物理学 37
# 実習 35
# 解析学 34
# 実験 31
# 情報 30
# 惑星 28
# III 25
# 情報科 20
# 代数学 20
# 代数 20
# 情報科学 18
# 幾何学 18
# 幾何 18
# 講 17
# V 17
# 統計 17
# 計算 17
# b 17
# a 17
# 人類 15
# 環境 15
# 研究 14
# 数理 14
# 講義 13
# Ⅱ 13
# 生物学 12
# 力学 12
# 環境学 12
# 統計学 12
# 倫理 11
# 倫 11
# 基礎 11
# 外 10
# 研究倫理 10
# 生命 10
# 確率統計 10
# 確率 10
# 人類学 9
# 植物 9
# 野外 9
# IV 9
# 進化 9
# 量 9
# 構 8
# システム 8
# シス 8
# 有機化学 8
# 有機 8
# 物理化学 8
# 文学 8
# 天文学 8
# 分子 8
# 量子 8
# A 8
# 応用 8
# B 8
# 数学I 8
# 生理 7
# 語 7
# 系 7
# 惑星物理学 7
# XA 7
# 応用数学 7
# XB 7
# 発生 6
# 動物 6
# 海洋 6
# 態 6
# 生体 6
# 法 6
# 理論 6
# 宇宙 6
# 物質 6
# 固体 6
# E 6
# XE 6
# C 6
# 複素解析 6
# 数理科学 6
# 発生学 5
# 生態 5
# 人体 5
# 生命科学 5
# 天体 5
# 間 5
# 体力 5
# Ⅲ 5
# 分析 5
# 無機 5
# 細胞 5
# XF 5
# Ib 5
# Ia 5
# XC 5
# D 5
# 理I 5
# 英語 4
# 英 4
# 遺伝 4
# 機構 4
# 生理学 4
# 性 4
# 大気 4
# Ⅳ 4
# および 4
# 調査 4
# 分析化学 4
# 専門 4
# XG 4
# XD 4
# 計算機 4
# ...
